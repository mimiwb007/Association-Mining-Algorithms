# %%
import pandas as pd
d1 = pd.read_csv(r"C:\Users\nibed\Desktop\Freelance\Frogs_MFCCs.csv")
d1.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
# ...

# %%
d2=d1[['Family','Genus','Species']]
d2.info()
d2.drop_duplicates(inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7195 entries, 0 to 7194
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Family   7195 non-null   object
#  1   Genus    7195 non-null   object
#  2   Species  7195 non-null   object
# dtypes: object(3)
# memory usage: 168.8+ KB
# C:\Users\nibed\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
observations=[]
for i in range(len(d2)):
    observations.append([str(d2.values[i,j]) for j in range(3)])

# %%
pip install pyfpgrowth
# Out:
# ...
#   Stored in directory: C:\Users\nibed\AppData\Local\pip\Cache\wheels\3b\3f\0d\a04bb8b17887c1eca7d0f1a48d4aa0c09c96eb221ff7fa56c1
# Successfully built pyfpgrowth
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyfpgrowth

# %%
#find_frequent_patterns to find patterns in baskets that occur over the support threshold:

patterns = pyfpgrowth.find_frequent_patterns(observations, 0.004)
patterns
# Out:
# {('AdenomeraAndre',): 1,
#  ('Adenomera', 'AdenomeraAndre'): 1,
#  ('AdenomeraAndre', 'Leptodactylidae'): 1,
#  ('Adenomera', 'AdenomeraAndre', 'Leptodactylidae'): 1,
#  ('Dendrobatidae',): 1,
#  ('Ameerega',): 1,
#  ('Ameerega', 'Dendrobatidae'): 1,
#  ('Ameeregatrivittata',): 1,
#  ('Ameerega', 'Ameeregatrivittata'): 1,
#  ('Ameeregatrivittata', 'Dendrobatidae'): 1,
#  ('Ameerega', 'Ameeregatrivittata', 'Dendrobatidae'): 1,
#  ('AdenomeraHylaedactylus',): 1,
#  ('Adenomera', 'AdenomeraHylaedactylus'): 1,
#  ('AdenomeraHylaedactylus', 'Leptodactylidae'): 1,
#  ('Adenomera', 'AdenomeraHylaedactylus', 'Leptodactylidae'): 1,
#  ('Dendropsophus',): 1,
#  ('Dendropsophus', 'Hylidae'): 1,
#  ('HylaMinuta',): 1,
#  ('Dendropsophus', 'HylaMinuta'): 1,
#  ('HylaMinuta', 'Hylidae'): 1,
#  ('Dendropsophus', 'HylaMinuta', 'Hylidae'): 1,
#  ('HypsiboasCinerascens',): 1,
#  ('Hypsiboas', 'HypsiboasCinerascens'): 1,
#  ('Hylidae', 'HypsiboasCinerascens'): 1,
# ...

# %%
patterns = pd.DataFrame(patterns.items())
patterns.columns = ['Label Sets','Frequency']
patterns.sort_values(by='Frequency',ascending=False,inplace=True)
patterns

# %%
#generate_association_rules to find patterns that are associated with another with a certain minimum probability
rules = pyfpgrowth.generate_association_rules(patterns, 0.5)

# %%
m=[]
for it,p in rules.items():
  
        m.append([it,p[0],p[1]])

# %%
m = pd.DataFrame(m)
m.columns = ['Label1','Label2','Probablity']
