# %%
import pandas as pd
d1 = pd.read_csv(r"C:\Users\nibed\Desktop\Freelance\Frogs_MFCCs.csv")
d1.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
# ...

# %%
d2=d1[['Family','Genus','Species']]
d2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7195 entries, 0 to 7194
# Data columns (total 3 columns):
# Family     7195 non-null object
# Genus      7195 non-null object
# Species    7195 non-null object
# dtypes: object(3)
# memory usage: 168.7+ KB

# %%
observations=[]

# %%
for i in range(len(d2)):
    observations.append([str(d2.values[i,j]) for j in range(3)])

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(observations).transform(observations)
df = pd.DataFrame(te_ary, columns=te.columns_)
df
# Out:
#       Adenomera  AdenomeraAndre  AdenomeraHylaedactylus  Ameerega  \
# 0          True            True                   False     False
# 1          True            True                   False     False
# 2          True            True                   False     False
# 3          True            True                   False     False
# 4          True            True                   False     False
# 5          True            True                   False     False
# 6          True            True                   False     False
# 7          True            True                   False     False
# 8          True            True                   False     False
# 9          True            True                   False     False
# 10         True            True                   False     False
# 11         True            True                   False     False
# 12         True            True                   False     False
# ...

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
frq_items = apriori(df, min_support=0.004, use_colnames=True)

# %%
# Collecting the inferred rules in a dataframe 
rules = association_rules(frq_items, metric ="lift", min_threshold = 1) 
rules
# Out:
#                                 antecedents  \
# 0                          (AdenomeraAndre)
# 1                               (Adenomera)
# 2                  (AdenomeraHylaedactylus)
# 3                               (Adenomera)
# 4                         (Leptodactylidae)
# 5                               (Adenomera)
# 6                          (AdenomeraAndre)
# 7                         (Leptodactylidae)
# 8                         (Leptodactylidae)
# 9                  (AdenomeraHylaedactylus)
# 10                     (Ameeregatrivittata)
# 11                               (Ameerega)
# 12                          (Dendrobatidae)
# 13                               (Ameerega)
# 14                     (Ameeregatrivittata)
# 15                          (Dendrobatidae)
# 16                               (Rhinella)
# 17                              (Bufonidae)
# 18                      (Rhinellagranulosa)
# 19                              (Bufonidae)
# ...

# %%
rules = rules[['antecedents','consequents','support','lift','confidence']]
rules
# Out:
#                                 antecedents  \
# 0                          (AdenomeraAndre)
# 1                               (Adenomera)
# 2                  (AdenomeraHylaedactylus)
# 3                               (Adenomera)
# 4                         (Leptodactylidae)
# 5                               (Adenomera)
# 6                          (AdenomeraAndre)
# 7                         (Leptodactylidae)
# 8                         (Leptodactylidae)
# 9                  (AdenomeraHylaedactylus)
# 10                     (Ameeregatrivittata)
# 11                               (Ameerega)
# 12                          (Dendrobatidae)
# 13                               (Ameerega)
# 14                     (Ameeregatrivittata)
# 15                          (Dendrobatidae)
# 16                               (Rhinella)
# 17                              (Bufonidae)
# 18                      (Rhinellagranulosa)
# 19                              (Bufonidae)
# ...
